# %% [markdown]
# ##### Input: N = 3
# ##### Output: Ashish Ashish Ashish
# #### Explanation: Name is printed 3 times.
# ##### Input: N = 1
# #### Output: Ashish
# ##### Explanation: Name is printed once.

# %%
def nameN(i,n):
    if i == n:
        return
    print("tej")
    nameN(i+1,n)

num = int(input())
n = nameN(1,num)
