# %%
# Brute Force Approach

n1 = 12345

dummy = n1
count = 0       # Initialise a counter to store the number of digits.

 
while n1 > 0:   # While N is greater than 0, execute the following:

    
    count +=1   # Increment the counter by 1

    n1 = n1//10 # remove the last digit of n1 in each iteration
    
print("The number {} has {} digits".format(dummy,count))
# Out:
# The number 12345 has 5 digits

# %%
import math

# %%
print(math.log10(1))
# Out:
# 0.0

# %%
print(math.log10(10))
# Out:
# 1.0

# %%
print(math.log10(12))
# Out:
# 1.0791812460476249

# %%
print(math.log10(100)) # 10^2
# Out:
# 2.0

# %%
print(math.log10(123))
# Out:
# 2.089905111439398

# %%
print(math.log10(1000))  #10^3
# Out:
# 3.0

# %%
print(math.log10(1234)) # 1234 has 4 digits but we are getting 3
# Out:
# 3.091315159697223

# %%
print(math.log10(1234)+1)  # we add 1 to get 4
# Out:
# 4.091315159697222

# %%
print(math.log10(10000))  #10^4
# Out:
# 4.0

# %%
print(math.log10(12345)) # 12345 has 5 digits we are getting 4
# Out:
# 4.091491094267951

# %%
print(math.log10(12345)+1) # by adding 1 we get 5 digits
# Out:
# 5.091491094267951

# %%
print(int(math.log10(12345)+1))   # convert to int
# Out:
# 5

# %%
# Optimal Approach

import math  

N = 12345

# Intialize the variable count and perform log base10 operations

count = int(math.log10(N)+1)

# log base 10 gives the number of digits in N
# We add 1 to ensure that count value is correct
# Even for that are powers of 10
# we convert to int to avoid floating numbers

print(count)
# Out:
# 5
