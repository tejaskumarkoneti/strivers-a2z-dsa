# %% [markdown]
# # Find the Largest Element in an Array
#
# ## Problem Statement
# Given an array, we have to find the largest element in the array.

# %% [markdown]
# ## Examples
#
# ### Example 1
# **Input:**
# `arr[] = {2, 5, 1, 3, 0}`
#
# **Output:**
# `5`
#
# **Explanation:**
# 5 is the largest element in the array.
#
# ---
#
# ### Example 2
# **Input:**
# `arr[] = {8, 10, 5, 7, 9}`
#
# **Output:**
# `10`
#
# **Explanation:**
# 10 is the largest element in the array.

# %% [markdown]
# # Brute Force Approach
#
# ## Algorithm
# 1. Sort the array in ascending order.
# 2. Print the last element of the array.
# 3. The last element will be the largest element.

# %%
# Function to sort the array and return the largest element
def sortArr(arr):
    # Sort the array in ascending order
    arr.sort()

    # Return the last element (largest element)
    return arr[-1]


arr1 = [2, 5, 1, 3, 0]
arr2 = [8, 10, 5, 7, 9]

# Find and output the largest element
print("The Largest element in the array is:", sortArr(arr1))
print("The Largest element in the array is:", sortArr(arr2))

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity:** `O(N log N)` because sorting is used.
# - **Space Complexity:** `O(1)` because constant extra space is used.

# %% [markdown]
# # Optimal Approach
#
# ## Algorithm
# 1. Create a variable `largest` and initialize it with the first element.
# 2. Traverse the array from index `1` to `n-1`.
# 3. Compare each element with `largest`.
# 4. If the current element is greater, update `largest`.
# 5. After traversal, `largest` will contain the maximum element.

# %%
# Function to find the largest element in the array
def findLargestElement(arr, n):
    largest = arr[0]  # Initialize with first element

    # Traverse the array
    for i in range(1, n):
        if arr[i] > largest:
            largest = arr[i]

    return largest


# Driver code
if __name__ == "__main__":
    arr1 = [2, 5, 1, 3, 0]
    arr2 = [8, 10, 5, 7, 9]

    print("The largest element in the array is:", findLargestElement(arr1, len(arr1)))
    print("The largest element in the array is:", findLargestElement(arr2, len(arr2)))

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity:** `O(N)` because we traverse the array once.
# - **Space Complexity:** `O(1)` because constant extra space is used.

# %% [markdown]
# # Dry Run Explanation
#
# We take the array:
#
# `[2, 5, 1, 3, 0]`
#
# - Start with `largest = 2`
# - Compare with `5` → update `largest = 5`
# - Compare with `1` → no change
# - Compare with `3` → no change
# - Compare with `0` → no change
#
# Final Answer = `5`

# %% [markdown]
# ### Step 1

# %%
from IPython.display import Image, display

display(Image(filename="/mnt/data/65b58a1d-75bc-44b0-93a5-80482d0de730.png"))

# %% [markdown]
# ### Step 2

# %%
from IPython.display import Image, display

display(Image(filename="/mnt/data/a488de27-5eab-4a14-9e44-c7ae301db393.png"))

# %% [markdown]
# ### Step 3

# %%
from IPython.display import Image, display

display(Image(filename="/mnt/data/259c77ee-c435-4956-b948-a9b84c558dde.png"))

# %% [markdown]
# ### Step 4

# %%
from IPython.display import Image, display

display(Image(filename="/mnt/data/fa3ed791-979d-404f-ae5e-e42c98b28154.png"))
